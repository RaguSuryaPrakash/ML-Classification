# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Social_Network_Ads.csv')
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0         True
# 1    15810944   35            20000          0         True
# 2    15668575   26            43000          0        False
# 3    15603246   27            57000          0        False
# 4    15804002   19            76000          0         True
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1        False
# 396  15706071   51            23000          1         True
# 397  15654296   50            20000          1        False
# 398  15755018   36            33000          0         True
# 399  15594041   49            36000          1        False
#
# [400 rows x 5 columns]

# %%
indep=dataset[['Age', 'EstimatedSalary','Gender_Male']]
dep=dataset['Purchased']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.naive_bayes import MultinomialNB

from sklearn.model_selection import GridSearchCV


# Assuming X_train, y_train, X_test, y_test are already defined

param_grid = {
    'alpha': [0.01, 0.1, 1.0, 2.0, 5.0],  # Smoothing parameter
    'fit_prior': [True, False]            # Whether to learn class prior probabilities
}
grid_search = GridSearchCV(estimator=MultinomialNB(), param_grid=param_grid, cv=5)

# Fit the model
grid_search.fit(X_train, y_train)

# Best parameters
print("Best Parameters:", grid_search.best_params_)
# Predictions
y_pred = grid_search.predict(X_test)


results = grid_search.cv_results_
#print(results)
# Out:
# Best Parameters: {'alpha': 0.01, 'fit_prior': True}

# %%
# Evaluate the model
from sklearn.metrics import accuracy_score
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6343283582089553

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print("confusion_matrix:\n",cm)
# Out:
# confusion_matrix:
#  [[85  0]
#  [49  0]]

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(y_test,y_pred)
# Out:
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.63      1.00      0.78        85
#            1       0.00      0.00      0.00        49
#
#     accuracy                           0.63       134
#    macro avg       0.32      0.50      0.39       134
# weighted avg       0.40      0.63      0.49       134

# %%
from sklearn.metrics import f1_score
f1_macro = f1_score(y_test, y_pred, average='macro')
print("F1 Macro Score for Best Parameters:", f1_macro)
# Out:
# F1 Macro Score for Best Parameters: 0.3881278538812785

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid_search.predict_proba(X_test)[:,1])
# Out:
# 0.5834333733493396

# %%
table=pd.DataFrame.from_dict(results)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0       0.004103      0.006081         0.004180        0.008359        0.01
# 1       0.000000      0.000000         0.000000        0.000000        0.01
# 2       0.000000      0.000000         0.003135        0.006269         0.1
# 3       0.003124      0.006248         0.000000        0.000000         0.1
# 4       0.000000      0.000000         0.003126        0.006253         1.0
# 5       0.000000      0.000000         0.002782        0.005563         1.0
# 6       0.001317      0.000420         0.000625        0.000511         2.0
# 7       0.001836      0.002709         0.000608        0.000497         2.0
# 8       0.000919      0.000535         0.000400        0.000490         5.0
# 9       0.001229      0.000780         0.011920        0.021837         5.0
#
#   param_fit_prior                               params  split0_test_score  \
# 0            True   {'alpha': 0.01, 'fit_prior': True}           0.648148
# 1           False  {'alpha': 0.01, 'fit_prior': False}           0.500000
# 2            True    {'alpha': 0.1, 'fit_prior': True}           0.648148
# 3           False   {'alpha': 0.1, 'fit_prior': False}           0.500000
# 4            True    {'alpha': 1.0, 'fit_prior': True}           0.648148
# 5           False   {'alpha': 1.0, 'fit_prior': False}           0.500000
# 6            True    {'alpha': 2.0, 'fit_prior': True}           0.648148
# 7           False   {'alpha': 2.0, 'fit_prior': False}           0.500000
# 8            True    {'alpha': 5.0, 'fit_prior': True}           0.648148
# 9           False   {'alpha': 5.0, 'fit_prior': False}           0.500000
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.679245           0.660377           0.698113           0.641509
# 1           0.603774           0.566038           0.471698           0.547170
# 2           0.679245           0.660377           0.698113           0.641509
# 3           0.603774           0.566038           0.471698           0.547170
# 4           0.679245           0.660377           0.698113           0.641509
# 5           0.603774           0.566038           0.471698           0.547170
# 6           0.679245           0.660377           0.698113           0.641509
# 7           0.603774           0.547170           0.471698           0.547170
# 8           0.679245           0.660377           0.698113           0.641509
# 9           0.584906           0.547170           0.471698           0.547170
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.665479        0.020763                1
# 1         0.537736        0.046981                6
# 2         0.665479        0.020763                1
# 3         0.537736        0.046981                6
# 4         0.665479        0.020763                1
# 5         0.537736        0.046981                6
# 6         0.665479        0.020763                1
# 7         0.533962        0.045283                9
# 8         0.665479        0.020763                1
# 9         0.530189        0.039757               10

# %%
age_input=float(input("Age:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:32
# Sex Male 0 or 1:0
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=grid_search.predict([[age_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[0]
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but MultinomialNB was fitted with feature names
#   warnings.warn(

# %%
from sklearn.naive_bayes import CategoricalNB

from sklearn.model_selection import GridSearchCV


# Assuming X_train, y_train, X_test, y_test are already defined

param_grid = {
    'alpha': [0.01, 0.1, 1.0, 2.0, 5.0],  # Smoothing parameter
    'fit_prior': [True, False]            # Whether to learn class prior probabilities
}
grid_search = GridSearchCV(estimator=CategoricalNB(), param_grid=param_grid, cv=5)

# Fit the model
grid_search.fit(X_train, y_train)

# Best parameters
print("Best Parameters:", grid_search.best_params_)
# Predictions
y_pred = grid_search.predict(X_test)


results = grid_search.cv_results_
#print(results)
# Out:
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:824: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 813, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 102, in predict
#     jll = self._joint_log_likelihood(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 1526, in _joint_log_likelihood
#     jll += self.feature_log_prob_[i][:, indices].T
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# IndexError: index 150000 is out of bounds for axis 1 with size 149001
#
#   warnings.warn(
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:824: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 813, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 102, in predict
#     jll = self._joint_log_likelihood(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 1526, in _joint_log_likelihood
#     jll += self.feature_log_prob_[i][:, indices].T
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# IndexError: index 150000 is out of bounds for axis 1 with size 149001
#
#   warnings.warn(
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:824: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 813, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 102, in predict
#     jll = self._joint_log_likelihood(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 1526, in _joint_log_likelihood
#     jll += self.feature_log_prob_[i][:, indices].T
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# IndexError: index 150000 is out of bounds for axis 1 with size 149001
#
#   warnings.warn(
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:824: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 813, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 102, in predict
#     jll = self._joint_log_likelihood(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 1526, in _joint_log_likelihood
#     jll += self.feature_log_prob_[i][:, indices].T
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# IndexError: index 150000 is out of bounds for axis 1 with size 149001
#
#   warnings.warn(
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:824: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 813, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 102, in predict
#     jll = self._joint_log_likelihood(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 1526, in _joint_log_likelihood
#     jll += self.feature_log_prob_[i][:, indices].T
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# IndexError: index 150000 is out of bounds for axis 1 with size 149001
#
#   warnings.warn(
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:824: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 813, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 102, in predict
#     jll = self._joint_log_likelihood(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 1526, in _joint_log_likelihood
#     jll += self.feature_log_prob_[i][:, indices].T
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# IndexError: index 150000 is out of bounds for axis 1 with size 149001
#
#   warnings.warn(
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:824: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 813, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 102, in predict
#     jll = self._joint_log_likelihood(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 1526, in _joint_log_likelihood
#     jll += self.feature_log_prob_[i][:, indices].T
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# IndexError: index 150000 is out of bounds for axis 1 with size 149001
#
#   warnings.warn(
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:824: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 813, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 102, in predict
#     jll = self._joint_log_likelihood(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 1526, in _joint_log_likelihood
#     jll += self.feature_log_prob_[i][:, indices].T
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# IndexError: index 150000 is out of bounds for axis 1 with size 149001
#
#   warnings.warn(
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:824: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 813, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 102, in predict
#     jll = self._joint_log_likelihood(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 1526, in _joint_log_likelihood
#     jll += self.feature_log_prob_[i][:, indices].T
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# IndexError: index 150000 is out of bounds for axis 1 with size 149001
#
#   warnings.warn(
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:824: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 813, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\metrics\_scorer.py", line 527, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py", line 705, in score
#     return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#                              ^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 102, in predict
#     jll = self._joint_log_likelihood(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\naive_bayes.py", line 1526, in _joint_log_likelihood
#     jll += self.feature_log_prob_[i][:, indices].T
#            ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# IndexError: index 150000 is out of bounds for axis 1 with size 149001
#
#   warnings.warn(
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# Best Parameters: {'alpha': 0.01, 'fit_prior': True}

# %%
# Evaluate the model
from sklearn.metrics import accuracy_score
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8283582089552238

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print("confusion_matrix:\n",cm)
# Out:
# confusion_matrix:
#  [[77  8]
#  [15 34]]

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(y_test,y_pred)
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87        85
#            1       0.81      0.69      0.75        49
#
#     accuracy                           0.83       134
#    macro avg       0.82      0.80      0.81       134
# weighted avg       0.83      0.83      0.83       134

# %%
from sklearn.metrics import f1_score
f1_macro = f1_score(y_test, y_pred, average='macro')
print("F1 Macro Score for Best Parameters:", f1_macro)
# Out:
# F1 Macro Score for Best Parameters: 0.8086546222139442

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid_search.predict_proba(X_test)[:,1])
# Out:
# 0.8351740696278511

# %%
table=pd.DataFrame.from_dict(results)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0       0.009439      0.005595         0.000873        0.000777        0.01
# 1       0.006251      0.007656         0.003123        0.006246        0.01
# 2       0.006250      0.007655         0.000000        0.000000         0.1
# 3       0.006248      0.007652         0.003125        0.006250         0.1
# 4       0.009376      0.007656         0.000000        0.000000         1.0
# 5       0.009351      0.008716         0.000406        0.000497         1.0
# 6       0.004794      0.006062         0.003534        0.006117         2.0
# 7       0.006250      0.007654         0.000000        0.000000         2.0
# 8       0.006248      0.007653         0.003124        0.006247         5.0
# 9       0.010194      0.008456         0.000200        0.000399         5.0
#
#   param_fit_prior                               params  split0_test_score  \
# 0            True   {'alpha': 0.01, 'fit_prior': True}           0.740741
# 1           False  {'alpha': 0.01, 'fit_prior': False}           0.740741
# 2            True    {'alpha': 0.1, 'fit_prior': True}           0.759259
# 3           False   {'alpha': 0.1, 'fit_prior': False}           0.740741
# 4            True    {'alpha': 1.0, 'fit_prior': True}           0.759259
# 5           False   {'alpha': 1.0, 'fit_prior': False}           0.759259
# 6            True    {'alpha': 2.0, 'fit_prior': True}           0.740741
# 7           False   {'alpha': 2.0, 'fit_prior': False}           0.777778
# 8            True    {'alpha': 5.0, 'fit_prior': True}           0.666667
# 9           False   {'alpha': 5.0, 'fit_prior': False}           0.759259
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.754717           0.716981           0.811321                NaN
# 1           0.754717           0.735849           0.811321                NaN
# 2           0.754717           0.716981           0.811321                NaN
# 3           0.754717           0.735849           0.849057                NaN
# 4           0.792453           0.698113           0.830189                NaN
# 5           0.830189           0.716981           0.867925                NaN
# 6           0.792453           0.679245           0.792453                NaN
# 7           0.811321           0.716981           0.849057                NaN
# 8           0.792453           0.679245           0.679245                NaN
# 9           0.773585           0.754717           0.849057                NaN
#
#    mean_test_score  std_test_score  rank_test_score
# 0              NaN             NaN                1
# 1              NaN             NaN                1
# 2              NaN             NaN                1
# 3              NaN             NaN                1
# 4              NaN             NaN                1
# 5              NaN             NaN                1
# 6              NaN             NaN                1
# 7              NaN             NaN                1
# 8              NaN             NaN                1
# 9              NaN             NaN                1

# %%
age_input=float(input("Age:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:43
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=grid_search.predict([[age_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[1]
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but CategoricalNB was fitted with feature names
#   warnings.warn(

# %%
from sklearn.naive_bayes import ComplementNB

from sklearn.model_selection import GridSearchCV


# Assuming X_train, y_train, X_test, y_test are already defined

param_grid = {
    'alpha': [0.01, 0.1, 1.0, 2.0, 5.0],  # Smoothing parameter
    'fit_prior': [True, False],           # Whether to learn class prior probabilities
    'norm': [True, False]                  # Whether to normalize the predicted probabilities
}
grid_search = GridSearchCV(estimator=ComplementNB(), param_grid=param_grid, cv=5)

# Fit the model
grid_search.fit(X_train, y_train)

# Best parameters
print("Best Parameters:", grid_search.best_params_)
# Predictions
y_pred = grid_search.predict(X_test)


results = grid_search.cv_results_
#print(results)
# Out:
# Best Parameters: {'alpha': 0.01, 'fit_prior': True, 'norm': False}

# %%
# Evaluate the model
from sklearn.metrics import accuracy_score
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5149253731343284

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print("confusion_matrix:\n",cm)
# Out:
# confusion_matrix:
#  [[40 45]
#  [20 29]]

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(y_test,y_pred)
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.47      0.55        85
#            1       0.39      0.59      0.47        49
#
#     accuracy                           0.51       134
#    macro avg       0.53      0.53      0.51       134
# weighted avg       0.57      0.51      0.52       134

# %%
from sklearn.metrics import f1_score
f1_macro = f1_score(y_test, y_pred, average='macro')
print("F1 Macro Score for Best Parameters:", f1_macro)
# Out:
# F1 Macro Score for Best Parameters: 0.5116344266890944

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid_search.predict_proba(X_test)[:,1])
# Out:
# 0.5834333733493396

# %%
table=pd.DataFrame.from_dict(results)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0        0.001689      0.000971         0.001480        0.001620        0.01
# 1        0.001190      0.000410         0.000807        0.000404        0.01
# 2        0.000000      0.000000         0.000000        0.000000        0.01
# 3        0.003134      0.006267         0.000000        0.000000        0.01
# 4        0.000000      0.000000         0.000000        0.000000         0.1
# 5        0.003124      0.006248         0.000000        0.000000         0.1
# 6        0.000000      0.000000         0.000000        0.000000         0.1
# 7        0.003125      0.006250         0.000000        0.000000         0.1
# 8        0.000000      0.000000         0.003124        0.006249         1.0
# 9        0.003126      0.006252         0.000000        0.000000         1.0
# 10       0.000000      0.000000         0.003124        0.006247         1.0
# 11       0.000000      0.000000         0.000000        0.000000         1.0
# 12       0.003668      0.004761         0.000790        0.000399         2.0
# 13       0.000000      0.000000         0.000000        0.000000         2.0
# 14       0.003010      0.006021         0.000000        0.000000         2.0
# 15       0.000000      0.000000         0.003135        0.006269         2.0
# 16       0.003126      0.006252         0.000000        0.000000         5.0
# 17       0.000000      0.000000         0.000000        0.000000         5.0
# 18       0.000000      0.000000         0.000000        0.000000         5.0
# 19       0.000000      0.000000         0.003124        0.006249         5.0
#
#    param_fit_prior param_norm  \
# 0             True       True
# 1             True      False
# 2            False       True
# 3            False      False
# 4             True       True
# 5             True      False
# 6            False       True
# 7            False      False
# 8             True       True
# 9             True      False
# 10           False       True
# 11           False      False
# 12            True       True
# 13            True      False
# 14           False       True
# 15           False      False
# 16            True       True
# 17            True      False
# 18           False       True
# 19           False      False
#
#                                                params  split0_test_score  \
# 0    {'alpha': 0.01, 'fit_prior': True, 'norm': True}           0.351852
# 1   {'alpha': 0.01, 'fit_prior': True, 'norm': False}           0.500000
# 2   {'alpha': 0.01, 'fit_prior': False, 'norm': True}           0.351852
# 3   {'alpha': 0.01, 'fit_prior': False, 'norm': Fa...           0.500000
# 4     {'alpha': 0.1, 'fit_prior': True, 'norm': True}           0.351852
# 5    {'alpha': 0.1, 'fit_prior': True, 'norm': False}           0.500000
# 6    {'alpha': 0.1, 'fit_prior': False, 'norm': True}           0.351852
# 7   {'alpha': 0.1, 'fit_prior': False, 'norm': False}           0.500000
# 8     {'alpha': 1.0, 'fit_prior': True, 'norm': True}           0.351852
# 9    {'alpha': 1.0, 'fit_prior': True, 'norm': False}           0.500000
# 10   {'alpha': 1.0, 'fit_prior': False, 'norm': True}           0.351852
# 11  {'alpha': 1.0, 'fit_prior': False, 'norm': False}           0.500000
# 12    {'alpha': 2.0, 'fit_prior': True, 'norm': True}           0.351852
# 13   {'alpha': 2.0, 'fit_prior': True, 'norm': False}           0.500000
# 14   {'alpha': 2.0, 'fit_prior': False, 'norm': True}           0.351852
# 15  {'alpha': 2.0, 'fit_prior': False, 'norm': False}           0.500000
# 16    {'alpha': 5.0, 'fit_prior': True, 'norm': True}           0.351852
# 17   {'alpha': 5.0, 'fit_prior': True, 'norm': False}           0.500000
# 18   {'alpha': 5.0, 'fit_prior': False, 'norm': True}           0.351852
# 19  {'alpha': 5.0, 'fit_prior': False, 'norm': False}           0.500000
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.339623           0.358491           0.358491
# 1            0.603774           0.566038           0.471698
# 2            0.339623           0.358491           0.358491
# 3            0.603774           0.566038           0.471698
# 4            0.339623           0.358491           0.358491
# 5            0.603774           0.566038           0.471698
# 6            0.339623           0.358491           0.358491
# 7            0.603774           0.566038           0.471698
# 8            0.339623           0.358491           0.358491
# 9            0.603774           0.566038           0.471698
# 10           0.339623           0.358491           0.358491
# 11           0.603774           0.566038           0.471698
# 12           0.339623           0.358491           0.358491
# 13           0.603774           0.547170           0.471698
# 14           0.339623           0.358491           0.358491
# 15           0.603774           0.547170           0.471698
# 16           0.339623           0.358491           0.358491
# 17           0.584906           0.547170           0.471698
# 18           0.339623           0.358491           0.358491
# 19           0.584906           0.547170           0.471698
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.358491         0.353389        0.007348               11
# 1            0.547170         0.537736        0.046981                1
# 2            0.358491         0.353389        0.007348               11
# 3            0.547170         0.537736        0.046981                1
# 4            0.358491         0.353389        0.007348               11
# 5            0.547170         0.537736        0.046981                1
# 6            0.358491         0.353389        0.007348               11
# 7            0.547170         0.537736        0.046981                1
# 8            0.358491         0.353389        0.007348               11
# 9            0.547170         0.537736        0.046981                1
# 10           0.358491         0.353389        0.007348               11
# 11           0.547170         0.537736        0.046981                1
# 12           0.358491         0.353389        0.007348               11
# 13           0.547170         0.533962        0.045283                7
# 14           0.358491         0.353389        0.007348               11
# 15           0.547170         0.533962        0.045283                7
# 16           0.358491         0.353389        0.007348               11
# 17           0.547170         0.530189        0.039757                9
# 18           0.358491         0.353389        0.007348               11
# 19           0.547170         0.530189        0.039757                9

# %%
age_input=float(input("Age:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:32
# Sex Male 0 or 1:0
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=grid_search.predict([[age_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[0]
# C:\Users\Malya\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but ComplementNB was fitted with feature names
#   warnings.warn(
