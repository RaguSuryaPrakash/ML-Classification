# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Social_Network_Ads.csv')

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0         True
# 1    15810944   35            20000          0         True
# 2    15668575   26            43000          0        False
# 3    15603246   27            57000          0        False
# 4    15804002   19            76000          0         True
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1        False
# 396  15706071   51            23000          1         True
# 397  15654296   50            20000          1        False
# 398  15755018   36            33000          0         True
# 399  15594041   49            36000          1        False
#
# [400 rows x 5 columns]

# %%
indep=dataset[['Age', 'EstimatedSalary','Gender_Male']]
dep=dataset['Purchased']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.naive_bayes import GaussianNB

from sklearn.model_selection import GridSearchCV


# Assuming X_train, y_train, X_test, y_test are already defined

param_grid = {
    'var_smoothing': [1e-9, 1e-8, 1e-7, 1e-6]  
}
grid_search = GridSearchCV(estimator=GaussianNB(), param_grid=param_grid, cv=5)

# Fit the model
grid_search.fit(X_train, y_train)

# Best parameters
print("Best Parameters:", grid_search.best_params_)
# Predictions
y_pred = grid_search.predict(X_test)


results = grid_search.cv_results_
#print(results)
# Out:
# Best Parameters: {'var_smoothing': 1e-09}

# %%
# Evaluate the model
from sklearn.metrics import accuracy_score
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9104477611940298

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print("confusion_matrix:\n",cm)
# Out:
# confusion_matrix:
#  [[81  4]
#  [ 8 41]]

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(y_test,y_pred)

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93        85
#            1       0.91      0.84      0.87        49
#
#     accuracy                           0.91       134
#    macro avg       0.91      0.89      0.90       134
# weighted avg       0.91      0.91      0.91       134

# %%
from sklearn.metrics import f1_score
f1_macro = f1_score(y_test, y_pred, average='macro')
print("F1 Macro Score for Best Parameters:", f1_macro)
# Out:
# F1 Macro Score for Best Parameters: 0.9016874541452677

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid_search.predict_proba(X_test)[:,1])
# Out:
# 0.9608643457382953

# %%
table=pd.DataFrame.from_dict(results)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.002927      0.005854         0.000000        0.000000
# 1       0.003242      0.006483         0.001872        0.003744
# 2       0.003033      0.003731         0.001602        0.003205
# 3       0.000000      0.000000         0.003125        0.006249
#
#   param_var_smoothing                    params  split0_test_score  \
# 0                 0.0  {'var_smoothing': 1e-09}           0.833333
# 1                 0.0  {'var_smoothing': 1e-08}           0.833333
# 2                 0.0  {'var_smoothing': 1e-07}           0.833333
# 3            0.000001  {'var_smoothing': 1e-06}           0.833333
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.867925           0.792453           0.962264           0.981132
# 1           0.867925           0.792453           0.962264           0.981132
# 2           0.867925           0.792453           0.962264           0.981132
# 3           0.867925           0.792453           0.962264           0.981132
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.887421        0.073086                1
# 1         0.887421        0.073086                1
# 2         0.887421        0.073086                1
# 3         0.887421        0.073086                1

# %%
age_input=float(input("Age:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:32
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=grid_search.predict([[age_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[1]

# %%
from sklearn.naive_bayes import BernoulliNB

from sklearn.model_selection import GridSearchCV


# Assuming X_train, y_train, X_test, y_test are already defined

param_grid = {
    'alpha': [0.01, 0.1, 1.0, 2.0, 5.0],  # Smoothing parameter
    'fit_prior': [True, False],           # Whether to learn class prior probabilities
    'binarize': [0.0, 0.1, 0.5, 1.0]      # Threshold for binarizing the feature
}

grid_search = GridSearchCV(estimator=BernoulliNB(), param_grid=param_grid, cv=5)

# Fit the model
grid_search.fit(X_train, y_train)

# Best parameters
print("Best Parameters:", grid_search.best_params_)
# Predictions
y_pred = grid_search.predict(X_test)


results = grid_search.cv_results_
#print(results)
# Out:
# Best Parameters: {'alpha': 0.01, 'binarize': 0.5, 'fit_prior': False}

# %%
# Evaluate the model
from sklearn.metrics import accuracy_score
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8656716417910447

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print("confusion_matrix:\n",cm)
# Out:
# confusion_matrix:
#  [[70 15]
#  [ 3 46]]

# %%
from sklearn.metrics import classification_report
clf_report=classification_report(y_test,y_pred)

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.82      0.89        85
#            1       0.75      0.94      0.84        49
#
#     accuracy                           0.87       134
#    macro avg       0.86      0.88      0.86       134
# weighted avg       0.88      0.87      0.87       134

# %%
from sklearn.metrics import f1_score
f1_macro = f1_score(y_test, y_pred, average='macro')
print("F1 Macro Score for Best Parameters:", f1_macro)
# Out:
# F1 Macro Score for Best Parameters: 0.8612197928653624

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid_search.predict_proba(X_test)[:,1])
# Out:
# 0.9165666266506602

# %%
table=pd.DataFrame.from_dict(results)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0         0.00307  4.656557e-03           0.0008        0.000749        0.01
# 1         0.00100  1.507891e-07           0.0004        0.000490        0.01
# 2         0.00060  4.898624e-04           0.0006        0.000490        0.01
# 3         0.00080  3.999472e-04           0.0004        0.000490        0.01
# 4         0.00060  4.899404e-04           0.0006        0.000490        0.01
# 5         0.00080  3.999949e-04           0.0006        0.000490        0.01
# 6         0.00060  4.898624e-04           0.0006        0.000490        0.01
# 7         0.00100  3.568323e-07           0.0004        0.000490        0.01
# 8         0.00080  3.999949e-04           0.0004        0.000490         0.1
# 9         0.00060  4.899404e-04           0.0006        0.000490         0.1
# 10        0.00080  4.000426e-04           0.0004        0.000490         0.1
# 11        0.00080  3.999949e-04           0.0004        0.000490         0.1
# 12        0.00080  3.999710e-04           0.0004        0.000490         0.1
# 13        0.00060  4.899793e-04           0.0004        0.000490         0.1
# 14        0.00080  3.999950e-04           0.0002        0.000400         0.1
# 15        0.00060  4.899403e-04           0.0004        0.000490         0.1
# 16        0.00060  4.898624e-04           0.0004        0.000490         1.0
# 17        0.00080  4.000187e-04           0.0004        0.000490         1.0
# 18        0.00080  4.000425e-04           0.0004        0.000490         1.0
# 19        0.00080  3.999949e-04           0.0006        0.000490         1.0
# 20        0.00060  4.898625e-04           0.0004        0.000490         1.0
# 21        0.00080  3.999949e-04           0.0002        0.000400         1.0
# 22        0.00060  4.899014e-04           0.0004        0.000490         1.0
# 23        0.00060  4.899014e-04           0.0004        0.000490         1.0
# 24        0.00080  4.000425e-04           0.0006        0.000490         2.0
# 25        0.00060  4.899014e-04           0.0006        0.000490         2.0
# 26        0.00060  4.898624e-04           0.0008        0.000400         2.0
# 27        0.00080  4.000187e-04           0.0006        0.000490         2.0
# 28        0.00060  4.899014e-04           0.0006        0.000490         2.0
# 29        0.00060  4.899793e-04           0.0008        0.000400         2.0
# 30        0.00080  4.000187e-04           0.0002        0.000400         2.0
# 31        0.00060  4.899014e-04           0.0004        0.000490         2.0
# 32        0.00060  4.899793e-04           0.0004        0.000490         5.0
# 33        0.00100  1.784161e-07           0.0002        0.000400         5.0
# 34        0.00100  1.168008e-07           0.0004        0.000490         5.0
# 35        0.00100  1.784161e-07           0.0004        0.000490         5.0
# 36        0.00100  1.168008e-07           0.0002        0.000400         5.0
# 37        0.00060  4.899793e-04           0.0008        0.000400         5.0
# 38        0.00080  3.999949e-04           0.0006        0.000490         5.0
# 39        0.00080  3.999949e-04           0.0004        0.000490         5.0
#
#    param_binarize param_fit_prior  \
# 0             0.0            True
# 1             0.0           False
# 2             0.1            True
# 3             0.1           False
# 4             0.5            True
# 5             0.5           False
# 6             1.0            True
# 7             1.0           False
# 8             0.0            True
# 9             0.0           False
# 10            0.1            True
# 11            0.1           False
# 12            0.5            True
# 13            0.5           False
# 14            1.0            True
# 15            1.0           False
# 16            0.0            True
# 17            0.0           False
# 18            0.1            True
# 19            0.1           False
# 20            0.5            True
# 21            0.5           False
# 22            1.0            True
# 23            1.0           False
# 24            0.0            True
# 25            0.0           False
# 26            0.1            True
# 27            0.1           False
# 28            0.5            True
# 29            0.5           False
# 30            1.0            True
# 31            1.0           False
# 32            0.0            True
# 33            0.0           False
# 34            0.1            True
# 35            0.1           False
# 36            0.5            True
# 37            0.5           False
# 38            1.0            True
# 39            1.0           False
#
#                                                params  split0_test_score  \
# 0   {'alpha': 0.01, 'binarize': 0.0, 'fit_prior': ...           0.740741
# 1   {'alpha': 0.01, 'binarize': 0.0, 'fit_prior': ...           0.722222
# 2   {'alpha': 0.01, 'binarize': 0.1, 'fit_prior': ...           0.740741
# 3   {'alpha': 0.01, 'binarize': 0.1, 'fit_prior': ...           0.759259
# 4   {'alpha': 0.01, 'binarize': 0.5, 'fit_prior': ...           0.851852
# 5   {'alpha': 0.01, 'binarize': 0.5, 'fit_prior': ...           0.851852
# 6   {'alpha': 0.01, 'binarize': 1.0, 'fit_prior': ...           0.833333
# 7   {'alpha': 0.01, 'binarize': 1.0, 'fit_prior': ...           0.833333
# 8   {'alpha': 0.1, 'binarize': 0.0, 'fit_prior': T...           0.740741
# 9   {'alpha': 0.1, 'binarize': 0.0, 'fit_prior': F...           0.722222
# 10  {'alpha': 0.1, 'binarize': 0.1, 'fit_prior': T...           0.740741
# 11  {'alpha': 0.1, 'binarize': 0.1, 'fit_prior': F...           0.759259
# 12  {'alpha': 0.1, 'binarize': 0.5, 'fit_prior': T...           0.851852
# 13  {'alpha': 0.1, 'binarize': 0.5, 'fit_prior': F...           0.851852
# 14  {'alpha': 0.1, 'binarize': 1.0, 'fit_prior': T...           0.833333
# 15  {'alpha': 0.1, 'binarize': 1.0, 'fit_prior': F...           0.833333
# 16  {'alpha': 1.0, 'binarize': 0.0, 'fit_prior': T...           0.740741
# 17  {'alpha': 1.0, 'binarize': 0.0, 'fit_prior': F...           0.722222
# 18  {'alpha': 1.0, 'binarize': 0.1, 'fit_prior': T...           0.740741
# 19  {'alpha': 1.0, 'binarize': 0.1, 'fit_prior': F...           0.759259
# 20  {'alpha': 1.0, 'binarize': 0.5, 'fit_prior': T...           0.851852
# 21  {'alpha': 1.0, 'binarize': 0.5, 'fit_prior': F...           0.851852
# 22  {'alpha': 1.0, 'binarize': 1.0, 'fit_prior': T...           0.833333
# 23  {'alpha': 1.0, 'binarize': 1.0, 'fit_prior': F...           0.833333
# 24  {'alpha': 2.0, 'binarize': 0.0, 'fit_prior': T...           0.740741
# 25  {'alpha': 2.0, 'binarize': 0.0, 'fit_prior': F...           0.722222
# 26  {'alpha': 2.0, 'binarize': 0.1, 'fit_prior': T...           0.740741
# 27  {'alpha': 2.0, 'binarize': 0.1, 'fit_prior': F...           0.759259
# 28  {'alpha': 2.0, 'binarize': 0.5, 'fit_prior': T...           0.851852
# 29  {'alpha': 2.0, 'binarize': 0.5, 'fit_prior': F...           0.851852
# 30  {'alpha': 2.0, 'binarize': 1.0, 'fit_prior': T...           0.833333
# 31  {'alpha': 2.0, 'binarize': 1.0, 'fit_prior': F...           0.833333
# 32  {'alpha': 5.0, 'binarize': 0.0, 'fit_prior': T...           0.740741
# 33  {'alpha': 5.0, 'binarize': 0.0, 'fit_prior': F...           0.722222
# 34  {'alpha': 5.0, 'binarize': 0.1, 'fit_prior': T...           0.740741
# 35  {'alpha': 5.0, 'binarize': 0.1, 'fit_prior': F...           0.759259
# 36  {'alpha': 5.0, 'binarize': 0.5, 'fit_prior': T...           0.851852
# 37  {'alpha': 5.0, 'binarize': 0.5, 'fit_prior': F...           0.851852
# 38  {'alpha': 5.0, 'binarize': 1.0, 'fit_prior': T...           0.833333
# 39  {'alpha': 5.0, 'binarize': 1.0, 'fit_prior': F...           0.833333
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0